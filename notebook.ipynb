# %% [markdown]
# # ✈️ Flight Prices Cleaning Notebook
#
# This notebook reads a CSV containing flight price data, cleans the 'price' column, filters out low prices, and sorts the data.

# %%
import re
import pandas as pd
import numpy as np

def duration_to_hours(duration_str):
    if isinstance(duration_str, str):
        hours = 0
        minutes = 0
        hr_match = re.search(r'(\d+)\s*hr', duration_str)
        min_match = re.search(r'(\d+)\s*min', duration_str)
        if hr_match:
            hours = int(hr_match.group(1))
        if min_match:
            minutes = int(min_match.group(1))
        
        # Guard: if minutes >= 60, normalize
        hours += minutes // 60
        minutes = minutes % 60

        total_hours = hours + minutes / 60
        return round(total_hours, 2)
    else:
        return None

# %% [markdown]
# ## 📖 Read and clean the CSV file

# %%
# Replace with your actual file path if needed
file_path = 'results\\1747686091.5883362\\results.csv'
df = pd.read_csv(file_path)

# Remove commas, convert to numeric, turn errors into NaN
df['price'] = pd.to_numeric(df['price'].astype(str).str.replace(',', ''), errors='coerce')
# Drop rows with NaN values in 'price' column
df = df.dropna(subset=['price'])

# Apply the duration_to_hours function to create a new column
df['duration_hours'] = df['duration'].apply(duration_to_hours)
# Drop rows with NaN values in 'duration_hours' column
df = df.dropna(subset=['duration_hours'])

# Add a new column 'days'
df['outbound'] = pd.to_datetime(df['outbound'])
df['inbound'] = pd.to_datetime(df['inbound'])
df['days'] = (df['inbound'] - df['outbound']).dt.days

# Remove rows containing 'RHO' in 'from' or 'to' columns
df = df[~df['to'].str.contains('RHO', na=False)]

# %% [markdown]
# ## 🔍 Remove durations up to X hours

# %%
df = df[df['duration_hours'] < 7]

# %% [markdown]
# ## 🔍 Remove prices up to X euro

# %%
df = df[df['price'] < 1000]

# %% [markdown]
# ## 📊 Sort by price ascending

# %%
df = df.sort_values(by='price', ascending=True)

# Final result
df.reset_index(drop=True, inplace=True)
df
# Out:
#         timestamp from   to   outbound    inbound  price  \
# 0    1.747686e+09  BLQ  AYT 2025-08-08 2025-08-23  428.0
# 1    1.747686e+09  VCE  AYT 2025-08-07 2025-08-22  436.0
# 2    1.747686e+09  BLQ  AYT 2025-08-08 2025-08-23  440.0
# 3    1.747686e+09  BLQ  AYT 2025-08-07 2025-08-22  440.0
# 4    1.747686e+09  BLQ  AYT 2025-08-07 2025-08-22  448.0
# ..            ...  ...  ...        ...        ...    ...
# 156  1.747686e+09  VCE  BJV 2025-08-07 2025-08-22  977.0
# 157  1.747686e+09  FCO  GZP 2025-08-09 2025-08-24  980.0
# 158  1.747686e+09  FCO  DLM 2025-08-09 2025-08-24  982.0
# 159  1.747686e+09  NAP  BJV 2025-08-07 2025-08-22  989.0
# 160  1.747686e+09  NAP  AYT 2025-08-07 2025-08-22  989.0
#
#                                    airline            time     duration  \
# 0    SWISS, SunExpressOperated by Helvetic  3:15PM 10:45PM  6 hr 30 min
# 1    SWISS, SunExpressOperated by Helvetic  2:50PM 10:45PM  6 hr 55 min
# 2                           3 hr 5 min VIE   1:25PM 8:55PM  6 hr 30 min
# 3                           3 hr 5 min VIE   9:50AM 5:20PM  6 hr 30 min
# 4        Air Dolomiti, SunExpressLufthansa   1:25PM 8:55PM  6 hr 30 min
# ..                                     ...             ...          ...
# 156                        1 hr 20 min IST   9:20AM 4:15PM  5 hr 55 min
# 157                       Turkish Airlines   7:00AM 2:55PM  6 hr 55 min
# 158                                Pegasus   7:00AM 1:35PM  5 hr 35 min
# 159                               FCO, SAW   9:20AM 4:15PM  5 hr 55 min
# 160  SWISS, SunExpressOperated by Helvetic   9:20AM 3:45PM  5 hr 25 min
#
#        type  duration_hours  days
# 0    1 stop            6.50    15
# 1    1 stop            6.92    15
# 2    1 stop            6.50    15
# 3    1 stop            6.50    15
# 4    1 stop            6.50    15
# ..      ...             ...   ...
# 156  1 stop            5.92    15
# 157  1 stop            6.92    15
# 158  1 stop            5.58    15
# 159  1 stop            5.92    15
# 160  1 stop            5.42    15
#
# [161 rows x 12 columns]

# %% [markdown]
# ## 📊  Find the cheapest flight per route

# %%
best_per_route = df.loc[df.groupby(['from', 'to'])['price'].idxmin()]
best_per_route
# Out:
#         timestamp from   to   outbound    inbound  price  \
# 56   1.747687e+09  BGY  AYT 2025-08-04 2025-08-19  608.0
# 46   1.747687e+09  BGY  BJV 2025-08-05 2025-08-20  567.0
# 43   1.747687e+09  BGY  DLM 2025-08-07 2025-08-22  567.0
# 0    1.747686e+09  BLQ  AYT 2025-08-08 2025-08-23  428.0
# 139  1.747686e+09  BLQ  DLM 2025-08-04 2025-08-19  872.0
# 23   1.747686e+09  FCO  AYT 2025-08-06 2025-08-21  503.0
# 24   1.747686e+09  FCO  BJV 2025-08-06 2025-08-21  503.0
# 52   1.747686e+09  FCO  DLM 2025-08-08 2025-08-23  591.0
# 132  1.747686e+09  FCO  GZP 2025-08-04 2025-08-19  870.0
# 8    1.747686e+09  LIN  AYT 2025-08-06 2025-08-21  463.0
# 12   1.747686e+09  MXP  AYT 2025-08-05 2025-08-20  478.0
# 5    1.747686e+09  NAP  AYT 2025-08-05 2025-08-20  457.0
# 104  1.747686e+09  NAP  BJV 2025-08-06 2025-08-21  771.0
# 63   1.747687e+09  PSA  AYT 2025-08-06 2025-08-21  632.0
# 22   1.747686e+09  TRN  AYT 2025-08-07 2025-08-22  495.0
# 130  1.747687e+09  TRN  BJV 2025-08-06 2025-08-21  863.0
# 131  1.747686e+09  TRN  DLM 2025-08-06 2025-08-21  863.0
# 1    1.747686e+09  VCE  AYT 2025-08-07 2025-08-22  436.0
# 106  1.747686e+09  VCE  BJV 2025-08-07 2025-08-22  774.0
# 75   1.747686e+09  VCE  DLM 2025-08-06 2025-08-21  677.0
#
#                                                airline             time  \
# 56   AJetOperated by Turkish Airlines, Turkish Airl...   12:45PM 7:50PM
# 46                        AJetOperated by BBN Airlines   12:45PM 7:20PM
# 43                    AJetOperated by Turkish Airlines   12:45PM 8:35PM
# 0                SWISS, SunExpressOperated by Helvetic   3:15PM 10:45PM
# 139                                   Turkish Airlines   2:55PM 10:00PM
# 23                                                AJet   12:30PM 7:00PM
# 24                    AJetOperated by Turkish Airlines   12:30PM 7:10PM
# 52                    AJetOperated by Turkish Airlines   12:30PM 7:05PM
# 132                                    3 hr 25 min CPH    7:00AM 2:55PM
# 8                                      2 hr 55 min FRA   10:40AM 6:25PM
# 12                                Austrian, SunExpress   2:45PM 10:35PM
# 5                SWISS, SunExpressOperated by Helvetic   2:50PM 10:45PM
# 104  Lufthansa, Discover AirlinesOperated by Luftha...   4:00PM 10:20PM
# 63                   Air Dolomiti, SunExpressLufthansa   10:30AM 6:25PM
# 22                                     5 hr 35 min MUC   10:05AM 5:20PM
# 130                                   11 hr 15 min MUC  7:10PM 2:55AM+1
# 131                                   Turkish Airlines  7:10PM 2:50AM+1
# 1                SWISS, SunExpressOperated by Helvetic   2:50PM 10:45PM
# 106                                   Turkish Airlines  7:55PM 2:55AM+1
# 75                                    Turkish Airlines  7:55PM 2:50AM+1
#
#         duration    type  duration_hours  days
# 56    6 hr 5 min  1 stop            6.08    15
# 46   5 hr 35 min  1 stop            5.58    15
# 43   6 hr 50 min  1 stop            6.83    15
# 0    6 hr 30 min  1 stop            6.50    15
# 139   6 hr 5 min  1 stop            6.08    15
# 23   5 hr 30 min  1 stop            5.50    15
# 24   5 hr 40 min  1 stop            5.67    15
# 52   5 hr 35 min  1 stop            5.58    15
# 132  6 hr 55 min  1 stop            6.92    15
# 8    6 hr 45 min  1 stop            6.75    15
# 12   6 hr 50 min  1 stop            6.83    15
# 5    6 hr 55 min  1 stop            6.92    15
# 104  5 hr 20 min  1 stop            5.33    15
# 63   6 hr 55 min  1 stop            6.92    15
# 22   6 hr 15 min  1 stop            6.25    15
# 130  6 hr 45 min  1 stop            6.75    15
# 131  6 hr 40 min  1 stop            6.67    15
# 1    6 hr 55 min  1 stop            6.92    15
# 106         6 hr  1 stop            6.00    15
# 75   5 hr 55 min  1 stop            5.92    15

# %% [markdown]
# ## 📊   Find the shortest flight per route

# %%
df['price_per_hour'] = (df['price'] / df['duration_hours']).round(2)
best_tradeoffs = df.sort_values(by='price_per_hour')
best_tradeoffs
# Out:
#         timestamp from   to   outbound    inbound  price  \
# 1    1.747686e+09  VCE  AYT 2025-08-07 2025-08-22  436.0
# 0    1.747686e+09  BLQ  AYT 2025-08-08 2025-08-23  428.0
# 6    1.747686e+09  NAP  AYT 2025-08-04 2025-08-19  457.0
# 5    1.747686e+09  NAP  AYT 2025-08-05 2025-08-20  457.0
# 3    1.747686e+09  BLQ  AYT 2025-08-07 2025-08-22  440.0
# ..            ...  ...  ...        ...        ...    ...
# 147  1.747686e+09  VCE  BJV 2025-08-07 2025-08-22  896.0
# 158  1.747686e+09  FCO  DLM 2025-08-09 2025-08-24  982.0
# 155  1.747686e+09  VCE  AYT 2025-08-04 2025-08-19  970.0
# 160  1.747686e+09  NAP  AYT 2025-08-07 2025-08-22  989.0
# 88   1.747686e+09  MXP  AYT 2025-08-08 2025-08-23  719.0
#
#                                      airline            time     duration  \
# 1      SWISS, SunExpressOperated by Helvetic  2:50PM 10:45PM  6 hr 55 min
# 0      SWISS, SunExpressOperated by Helvetic  3:15PM 10:45PM  6 hr 30 min
# 6    SWISS, SunExpressOperated by Air Baltic  2:50PM 10:45PM  6 hr 55 min
# 5      SWISS, SunExpressOperated by Helvetic  2:50PM 10:45PM  6 hr 55 min
# 3                             3 hr 5 min VIE   9:50AM 5:20PM  6 hr 30 min
# ..                                       ...             ...          ...
# 147                                 2 hr IST   2:05PM 8:20PM  5 hr 15 min
# 158                                  Pegasus   7:00AM 1:35PM  5 hr 35 min
# 155                                  Pegasus   2:55PM 9:20PM  5 hr 25 min
# 160    SWISS, SunExpressOperated by Helvetic   9:20AM 3:45PM  5 hr 25 min
# 88                                SunExpress   5:15PM 9:30PM  3 hr 15 min
#
#         type  duration_hours  days  price_per_hour
# 1     1 stop            6.92    15           63.01
# 0     1 stop            6.50    15           65.85
# 6     1 stop            6.92    15           66.04
# 5     1 stop            6.92    15           66.04
# 3     1 stop            6.50    15           67.69
# ..       ...             ...   ...             ...
# 147   1 stop            5.25    15          170.67
# 158   1 stop            5.58    15          175.99
# 155   1 stop            5.42    15          178.97
# 160   1 stop            5.42    15          182.47
# 88   Nonstop            3.25    15          221.23
#
# [161 rows x 13 columns]

# %% [markdown]
# ## 💾 Save results to CSV file

# %%
df = df.drop(columns=['duration_hours'])
df.to_csv(f'{file_path}_cleaned.csv', index=False)
